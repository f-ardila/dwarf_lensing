# %%
import corner
import numpy as np
import matplotlib.pyplot as plt
from functions import *
# Out:
# 3.0rc1

# %%
config = parse_config('/Users/fardila/Documents/GitHub/dwarf_lensing/MCMC/mcmc_test_config.yaml')

# %%
mcmc_array = np.load(config['mcmc_out_dir']+'cosmos_bplanck_run.npz')

# %%
mcmc_array.keys()
# Out:
# ['acceptance', 'lnprob', 'samples', 'position', 'chains', 'best']

# %%
samples = mcmc_array['samples']

# %%
for i in range(10):
    samples = np.append(samples,samples, axis=0)
print samples
# Out:
# [[ 0.37060149  0.1110201  12.68764506 ...  0.5506649   0.4687745
#    1.46784972]
#  [ 0.37060149  0.1110201  12.68764506 ...  0.5506649   0.4687745
#    1.46784972]
#  [ 0.37231956  0.0705912  12.69335072 ...  0.52868624  0.40508734
#    1.45455339]
#  ...
#  [ 0.37060149  0.1110201  12.68764506 ...  0.5506649   0.4687745
#    1.46784972]
#  [ 0.37231956  0.0705912  12.69335072 ...  0.52868624  0.40508734
#    1.45455339]
#  [ 0.37231956  0.0705912  12.69335072 ...  0.52868624  0.40508734
#    1.45455339]]

# %%
fig = corner.corner(samples, labels=config['param_labels_latex'],
                      truths=config['param_ini'], truth_color='r')
#fig.savefig("triangle.png")
# Out:
# WARNING:root:Too few points to create valid contours
# WARNING:root:Too few points to create valid contours
# WARNING:root:Too few points to create valid contours
# WARNING:root:Too few points to create valid contours
# WARNING:root:Too few points to create valid contours
# WARNING:root:Too few points to create valid contours
# WARNING:root:Too few points to create valid contours
# WARNING:root:Too few points to create valid contours
# WARNING:root:Too few points to create valid contours
# WARNING:root:Too few points to create valid contours
# WARNING:root:Too few points to create valid contours
# WARNING:root:Too few points to create valid contours
# WARNING:root:Too few points to create valid contours
# WARNING:root:Too few points to create valid contours
# WARNING:root:Too few points to create valid contours
# WARNING:root:Too few points to create valid contours
# WARNING:root:Too few points to create valid contours
# WARNING:root:Too few points to create valid contours
# WARNING:root:Too few points to create valid contours
# WARNING:root:Too few points to create valid contours
# WARNING:root:Too few points to create valid contours
