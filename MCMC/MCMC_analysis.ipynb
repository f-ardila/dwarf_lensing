# %%
import corner
import numpy as np
import matplotlib.pyplot as plt
from functions import *
# Out:
# 3.0rc1

# %%
config = parse_config('/Users/fardila/Documents/GitHub/dwarf_lensing/MCMC/mcmc_test_config.yaml')

# %% [markdown]
# ## burn-in

# %%
mcmc_array = np.load(config['mcmc_out_dir']+'cosmos_bplanck_burnin.npz')
mcmc_array.keys()
burnin_samples = mcmc_array['samples']

# %%
fig = corner.corner(burnin_samples, labels=config['param_labels_latex'],
                      truths=config['param_ini'], truth_color='r')

# %% [markdown]
# ## post burnin

# %%
mcmc_array = np.load(config['mcmc_out_dir']+'cosmos_bplanck_run.npz')
mcmc_array.keys()
samples = mcmc_array['samples']

# %%
fig = corner.corner(samples, labels=config['param_labels_latex'],
                      truths=config['param_ini'], truth_color='r')
#fig.savefig("triangle.png")

# %% [markdown]
# ## burnin + post-burnin

# %%
burnin_run_samples = np.append(burnin_samples, samples, axis=0 )

# %%
fig = corner.corner(burnin_run_samples, labels=config['param_labels_latex'],
                      truths=config['param_ini'], truth_color='r')
